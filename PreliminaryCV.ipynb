# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# import dbcollection as dbc
import os
from ultralytics import YOLO

# Load a pretrained YOLO model (recommended for training)
model = YOLO('yolov8s.pt')

# Train the model using the 'coco128.yaml' dataset for 3 epochs
results = model.train(data='coco128.yaml', epochs=3)

# Evaluate the model's performance on the validation set
results = model.val()

# Perform object detection on an image using the model
results = model('https://ultralytics.com/images/bus.jpg')
# Out:
# Ultralytics YOLOv8.0.114 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# ...

# %%
results = model.predict('/content/bus.jpg') # get model's prediction on random image NOT within dataset
# Out:
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 501.7ms
# Speed: 3.7ms preprocess, 501.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(results[0].plot())

# %%
result2 = model.predict('/content/alma_test.png')
cv2_imshow(result2[0].plot())

# %%
result3 = model.predict('/content/quad_test.png')
cv2_imshow(result3[0].plot())
# Out:
# image 1/1 /content/quad_test.png: 320x640 4 persons, 509.3ms
# Speed: 8.7ms preprocess, 509.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=1071x532 at 0x7F2D6D0D0160>
